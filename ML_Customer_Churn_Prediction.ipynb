# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-49ffcbca-4cc8-4694-818f-878336e989f7" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-49ffcbca-4cc8-4694-818f-878336e989f7">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

df = pd.read_csv("churn_data.csv")
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_463/1032753292.py in <cell line: 0>()
#       1 import pandas as pd
#       2
# ----> 3 df = pd.read_csv("churn_data.csv")
#       4 df.head()
#
# ...

# %%
df = pd.read_excel("churn_data.csv.xlsx")
df.head()
# Out:
#    CustomerID  Age  Gender  Tenure  MonthlyCharges ContractType  \
# 0           1   25    Male      12             500      Monthly
# 1           2   30  Female      24             700       Yearly
# 2           3   45    Male      36             800       Yearly
# 3           4   22  Female       6             300      Monthly
# 4           5   50    Male      60             900       Yearly
#
#   InternetService PaymentMethod  Churn
# 0           Fiber           UPI      1
# 1             DSL   Credit Card      0
# 2           Fiber    Debit Card      0
# 3             NaN          Cash      1
# 4           Fiber           UPI      0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   CustomerID       25 non-null     int64
#  1   Age              25 non-null     int64
#  2   Gender           25 non-null     object
#  3   Tenure           25 non-null     int64
#  4   MonthlyCharges   25 non-null     int64
#  5   ContractType     25 non-null     object
#  6   InternetService  20 non-null     object
#  7   PaymentMethod    25 non-null     object
#  8   Churn            25 non-null     int64
# dtypes: int64(5), object(4)
# memory usage: 1.9+ KB

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

df['Gender'] = le.fit_transform(df['Gender'])
df['ContractType'] = le.fit_transform(df['ContractType'])
df['InternetService'] = le.fit_transform(df['InternetService'])
df['PaymentMethod'] = le.fit_transform(df['PaymentMethod'])

df.head()
# Out:
#    CustomerID  Age  Gender  Tenure  MonthlyCharges  ContractType  \
# 0           1   25       1      12             500             0
# 1           2   30       0      24             700             1
# 2           3   45       1      36             800             1
# 3           4   22       0       6             300             0
# 4           5   50       1      60             900             1
#
#    InternetService  PaymentMethod  Churn
# 0                1              3      1
# 1                0              1      0
# 2                1              2      0
# 3                2              0      1
# 4                1              3      0

# %%
X = df.drop('Churn', axis=1)
y = df['Churn']

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
from sklearn.linear_model import LogisticRegression

model = LogisticRegression()
model.fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
model = LogisticRegression(max_iter=1000)
model.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %%
from sklearn.linear_model import LogisticRegression

model = LogisticRegression(max_iter=1000)
model.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %%
from sklearn.linear_model import LogisticRegression

model = LogisticRegression(max_iter=1000)
model.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %%
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

print("Accuracy:", accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 1.0

# %%
import matplotlib.pyplot as plt

plt.scatter(y_test, y_pred)
plt.xlabel("Actual")
plt.ylabel("Predicted")
plt.title("Actual vs Predicted")
plt.show()

# %% [markdown]
# This project predicts customer churn using Logistic Regression.
# Data preprocessing was performed to convert categorical data into numerical format.
# The model was trained and tested successfully.
# The model achieved an accuracy of 1.0, indicating high performance on the dataset.
